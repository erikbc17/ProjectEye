# %%
import os
import sys
import random
import glob
from tqdm import tqdm
import xml.etree.ElementTree as ET

import cv2 
import shutil

# %%
def Write_TXT(txt_file, data_list):
    fd  = open(txt_file, 'w')
    for data in data_list:
        fd.write(data)
        fd.write('\n')
    fd.close()

def parse_xml(xml_path):
    root = ET.parse(fn).getroot()
    filename = root.find('filename').text 
    width  = float(root.find('size').find('width').text)
    height = float(root.find('size').find('height').text)
    
    bboxs = []
    for obj in root.findall('object'):
        xmin = float(obj.find('bndbox').find('xmin').text)
        ymin = float(obj.find('bndbox').find('ymin').text)
        xmax = float(obj.find('bndbox').find('xmax').text)
        ymax = float(obj.find('bndbox').find('ymax').text)
        '''
        xc = (xmin+xmax)/2/width 
        yc = float(ymin+ymax)/2/height 
        w  = (xmax-xmin)/width
        h = (ymax-ymin)/height
        '''        
        bboxs.append((xmin,ymin,xmax,ymax))

    return bboxs

# %%
fn = './detector/gun/Train/Annotations/ia_100000004463.xml'
bboxs = parse_xml(fn)
print(bboxs)
# Out:
# [(39.0, 33.0, 58.0, 58.0), (61.0, 32.0, 85.0, 57.0), (84.0, 29.0, 103.0, 59.0), (103.0, 31.0, 127.0, 60.0), (124.0, 33.0, 146.0, 60.0), (145.0, 28.0, 167.0, 56.0), (174.0, 29.0, 194.0, 58.0), (199.0, 25.0, 221.0, 56.0), (185.0, 55.0, 212.0, 84.0), (163.0, 58.0, 187.0, 88.0), (180.0, 104.0, 208.0, 139.0), (156.0, 109.0, 183.0, 142.0), (137.0, 108.0, 162.0, 144.0), (144.0, 56.0, 161.0, 90.0), (122.0, 58.0, 140.0, 88.0), (128.0, 83.0, 152.0, 114.0), (97.0, 58.0, 120.0, 88.0), (72.0, 56.0, 94.0, 89.0), (50.0, 62.0, 69.0, 90.0), (28.0, 64.0, 53.0, 93.0), (34.0, 90.0, 59.0, 120.0), (60.0, 89.0, 80.0, 121.0), (82.0, 88.0, 101.0, 119.0), (102.0, 84.0, 125.0, 118.0), (92.0, 116.0, 113.0, 150.0), (116.0, 116.0, 137.0, 149.0), (66.0, 120.0, 85.0, 153.0), (44.0, 124.0, 63.0, 155.0), (22.0, 125.0, 40.0, 158.0)]

# %%
TRAIN_PATH = './detector/gun/Train/JPEGImages/'
base_images = glob.glob(TRAIN_PATH + '*.jpg')
random.shuffle(base_images)
print(len(base_images))
# Out:
# 44753

# %%
from matplotlib import pyplot as plt

# %%
for idx, img in enumerate(tqdm(base_images)):
    
    print("idx = {} processing image {}".format(idx,img))
    
    tmp = img.split('/')
    imgname = tmp[-1]
    imgbasename = imgname.split('.')[0]
    
    annodir =  '/'.join(tmp[:-2])+'/Annotations'
    annofn = annodir +  '/{}.xml'.format(imgbasename)
    absimgpath =  os.path.abspath(img)
    
    bboxs = parse_xml(annofn)
    
    img=cv2.imread(img)

    plt.subplot(4,10,idx+1),plt.imshow(img)
   
    
    if idx+1>=40:
        break
        
plt.show()
# Out:
#   0%|          | 1/44753 [00:00<1:23:31,  8.93it/s]
# idx = 0 processing image ./detector/gun/Train/JPEGImages/gun_5m_static_0001296.jpg
# idx = 1 processing image ./detector/gun/Train/JPEGImages/MightyQ_08.jpg
# idx = 2 processing image ./detector/gun/Train/JPEGImages/The_Sign_of_Four-1923-Bulldog-3.jpg
# idx = 3 processing image ./detector/gun/Train/JPEGImages/Jaguar-Shotgun-2.jpg
#   0%|          | 7/44753 [00:00<54:31, 13.68it/s]
# idx = 4 processing image ./detector/gun/Train/JPEGImages/7_7_asd_00131546.jpg
# idx = 5 processing image ./detector/gun/Train/JPEGImages/Mask_of_Death-Rossi971-1.jpg
# idx = 6 processing image ./detector/gun/Train/JPEGImages/1065638_00__01260.jpg
# idx = 7 processing image ./detector/gun/Train/JPEGImages/6_22_4_0007212.jpg
# idx = 8 processing image ./detector/gun/Train/JPEGImages/gun_3_1_1__0001764.jpg
#   0%|          | 13/44753 [00:00<43:38, 17.09it/s]
# idx = 9 processing image ./detector/gun/Train/JPEGImages/image45.jpg
# idx = 10 processing image ./detector/gun/Train/JPEGImages/10246941_624.jpg
# idx = 11 processing image ./detector/gun/Train/JPEGImages/IntoTheWhite-Krag2.jpg
# idx = 12 processing image ./detector/gun/Train/JPEGImages/11_12_372.jpg
# idx = 13 processing image ./detector/gun/Train/JPEGImages/6_22_4_0002780.jpg
#   0%|          | 18/44753 [00:00<42:31, 17.53it/s]
# idx = 14 processing image ./detector/gun/Train/JPEGImages/6_22_3_0002860.jpg
# idx = 15 processing image ./detector/gun/Train/JPEGImages/30DONsnub-5.jpg
# idx = 16 processing image ./detector/gun/Train/JPEGImages/6_22_4_0009020.jpg
# idx = 17 processing image ./detector/gun/Train/JPEGImages/gun_4m_static_0001640.jpg
# idx = 18 processing image ./detector/gun/Train/JPEGImages/FPWL_SOSG.jpg
#   0%|          | 24/44753 [00:01<42:35, 17.50it/s]
# idx = 19 processing image ./detector/gun/Train/JPEGImages/gun_3_3_1__0000156.jpg
# idx = 20 processing image ./detector/gun/Train/JPEGImages/CdmP_Python_04.jpg
# idx = 21 processing image ./detector/gun/Train/JPEGImages/KaDMP5.jpg
# idx = 22 processing image ./detector/gun/Train/JPEGImages/6_22_1_0003160.jpg
# idx = 23 processing image ./detector/gun/Train/JPEGImages/AcrossPacific42-COP1.jpg
# idx = 24 processing image ./detector/gun/Train/JPEGImages/BTTF3_009.jpg
#   0%|          | 28/44753 [00:01<37:26, 19.91it/s]
# idx = 25 processing image ./detector/gun/Train/JPEGImages/Gun_1051.jpg
# idx = 26 processing image ./detector/gun/Train/JPEGImages/BeCoolRev_2.jpg
# idx = 27 processing image ./detector/gun/Train/JPEGImages/6_22_2_0004072.jpg
# idx = 28 processing image ./detector/gun/Train/JPEGImages/Le_Battant-Python-4.jpg
# idx = 29 processing image ./detector/gun/Train/JPEGImages/gun1_4m_static_0002280.jpg
# idx = 30 processing image ./detector/gun/Train/JPEGImages/Fledos-015.jpg
# idx = 31 processing image ./detector/gun/Train/JPEGImages/6_22_1_0002208.jpg
#   0%|          | 36/44753 [00:01<31:28, 23.68it/s]
# idx = 32 processing image ./detector/gun/Train/JPEGImages/Jar3_08.jpg
# idx = 33 processing image ./detector/gun/Train/JPEGImages/Ninja_III-SW10-2.jpg
# idx = 34 processing image ./detector/gun/Train/JPEGImages/Gun_2584.jpg
# idx = 35 processing image ./detector/gun/Train/JPEGImages/2955959_02__72268.jpg
# idx = 36 processing image ./detector/gun/Train/JPEGImages/6_22_1_0000784.jpg
# idx = 37 processing image ./detector/gun/Train/JPEGImages/7_7_asd_00115274.jpg
#   0%|          | 39/44753 [00:01<33:31, 22.23it/s]
# idx = 38 processing image ./detector/gun/Train/JPEGImages/107556_01__00515.jpg
# idx = 39 processing image ./detector/gun/Train/JPEGImages/BaytownOutlaws-Saiga12K-05.jpg
